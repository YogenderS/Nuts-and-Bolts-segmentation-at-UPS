# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('June 2022 DM.XLSX')

# %%
df.head()
# Out:
#             Customer_name                   Description Material Group  \
# 0  M/S RAJESH ENTERPRISES    HHB M20X100 GR 10.9 BLACK*       HEX HEAD
# 1  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 2  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 3  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 4     LPS BOSSARD PVT LTD  M6 X 16 SHCS (B16) Zn PHOSP*           SHCS
#
#    Invoice_Quantity  Unit_Weight(Grams)    Part_Size  Net_Weight(KG)  \
# 0             23000          299.200000  Extra Heavy         6881.60
# 1             90340           64.599956        Heavy         5835.96
# 2             67615           64.600015        Heavy         4367.93
# 3             60000           64.600000        Heavy         3876.00
# 4            213500            5.750023  Extra Light         1227.63
#
#    Sales_Amount_(INR) Sales_Organization  Material_Cost   Sales_Person  \
# ...

# %%
df.shape
# Out:
# (2026, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_name          2026 non-null   object
#  1   Description            2026 non-null   object
#  2   Material Group         2026 non-null   object
#  3   Invoice_Quantity       2026 non-null   int64
#  4   Unit_Weight(Grams)     2026 non-null   float64
#  5   Part_Size              2026 non-null   object
#  6   Net_Weight(KG)         2026 non-null   float64
#  7   Sales_Amount_(INR)     2026 non-null   float64
#  8   Sales_Organization     2026 non-null   object
#  9   Material_Cost          2026 non-null   float64
#  10  Sales_Person           2026 non-null   object
#  11  Sub_Group              2025 non-null   object
#  12  Sub_Group_Description  2024 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 205.9+ KB

# %%
df.describe()
# Out:
#        Invoice_Quantity  Unit_Weight(Grams)  Net_Weight(KG)  \
# count       2026.000000         2026.000000      2026.00000
# mean        1867.649062          127.148157        66.81887
# std         7177.449008          207.622165       294.31381
# min            5.000000            0.120000         0.08000
# 25%          120.000000           15.025000         6.86000
# 50%          400.000000           46.500000        19.04000
# 75%         1000.000000          139.750000        39.00000
# max       213500.000000         3140.000000      6881.60000
#
#        Sales_Amount_(INR)  Material_Cost
# count        2.026000e+03   2.026000e+03
# mean         1.514424e+04   1.093005e+04
# std          5.580465e+04   4.467560e+04
# min          1.821600e+02   0.000000e+00
# 25%          1.935367e+03   1.057050e+03
# 50%          4.409455e+03   2.902875e+03
# 75%          9.332075e+03   6.105375e+03
# max          1.092270e+06   1.077320e+06

# %%
# Check for duplicate data

dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 77
#                            Customer_name                       Description  \
# 35                  SPM AUTOCOMP SYSTEMS    M8x1.25 x30 Double ended stud*
# 123                MINDA CORPORATION LTD                 HHS M 6 X 14 MPH*
# 203                    SANGHVI FASTENERS         HHS M24X50 GR 10.9 BLACK*
# 215                          NEHAL TOOLS   SHCS M3  x  10 12.9 F/T BLACK *
# 226                      POOJA LOGISTICS    CSK M6  x  20 12.9 F/T BLACK *
# ...                                  ...                               ...
# 1908                 SANDEEP ENGINEERING  SHCS M10  x  50 12.9 H/T BLACK *
# 1920                 SANDEEP ENGINEERING        SHCS M8X75 12.9 H/T BLACK*
# 1946                 SANDEEP ENGINEERING   SHCS M5  x  60 12.9 H/T BLACK *
# 1967  BENSONS FASTNERS & PRECESSION ENGG  SHCS M10  x  30 12.9 F/T BLACK *
# 1973                 SANDEEP ENGINEERING  SHCS M12  x  40 12.9 F/T BLACK *
#
# ...

# %%
df.columns
# Out:
# Index(['Customer_name', 'Description', 'Material Group', 'Invoice_Quantity',
#        'Unit_Weight(Grams)', 'Part_Size', 'Net_Weight(KG)',
#        'Sales_Amount_(INR)', 'Sales_Organization', 'Material_Cost',
#        'Sales_Person', 'Sub_Group', 'Sub_Group_Description'],
#       dtype='object')

# %%
df.head(5)
# Out:
#             Customer_name                   Description Material Group  \
# 0  M/S RAJESH ENTERPRISES    HHB M20X100 GR 10.9 BLACK*       HEX HEAD
# 1  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 2  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 3  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 4     LPS BOSSARD PVT LTD  M6 X 16 SHCS (B16) Zn PHOSP*           SHCS
#
#    Invoice_Quantity  Unit_Weight(Grams)    Part_Size  Net_Weight(KG)  \
# 0             23000          299.200000  Extra Heavy         6881.60
# 1             90340           64.599956        Heavy         5835.96
# 2             67615           64.600015        Heavy         4367.93
# 3             60000           64.600000        Heavy         3876.00
# 4            213500            5.750023  Extra Light         1227.63
#
#    Sales_Amount_(INR) Sales_Organization  Material_Cost   Sales_Person  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer_name            0
# Description              0
# Material Group           0
# Invoice_Quantity         0
# Unit_Weight(Grams)       0
# Part_Size                0
# Net_Weight(KG)           0
# Sales_Amount_(INR)       0
# Sales_Organization       0
# Material_Cost            0
# Sales_Person             0
# Sub_Group                1
# Sub_Group_Description    2
# dtype: int64

# %%
df.Customer_name.unique()
# Out:
# array(['M/S RAJESH ENTERPRISES', 'LPS BOSSARD PVT LTD',
#        'NAV BHARAT SUPPLY STORE', 'ECOPPIA SCIENTIFIC LLP',
#        'LUBRO AIR ENGINEER', 'CARLISLE TRADING AND MANUFACTURING',
#        'KALINGA INDUSTRIAL SUPPLIER', 'SPM AUTOCOMP SYSTEMS',
#        'M/S SAROJ HARDWARE, JAMSHEDPUR.', 'GARRETT MOTION TECHNOLOGIES',
#        'BAJAJ MOTORS LIMITED', 'MAA BHAGWATI TRADERS',
#        'COGEME PRECISION PARTS INDIA PVT. L',
#        'SUNSHINE AGENCIES (INDIA) LLP', 'VHS FASTNERS AND ENGINEERS',
#        'BENSONS FASTNERS & PRECESSION ENGG', 'MANOJ TRADERS',
#        'KANTILAL & BROTHERS', 'UNIVERSAL PRECISION SCREWS',
#        'SANGHVI ENTERPRISES', 'M Y ENTERPRISES',
#        'DHANKOT ENGINEERING PRIVATE LIMITED', 'SWAROOP ENTERPRISE',
#        'DEV ENTERPRISE CORPORATION', 'WIRESYS AUTO',
#        'BHARAT BOLT AGENCIES', 'GAMARIA TRADE CENTRE',
#        'SANDEEP ENGINEERING', 'SANGHVI FASTENERS',
#        'JAY AMBAY ENTERPRISES', 'SAPANI FASTENERS', 'KISHAN ENTERPRISES',
# ...

# %%
df[['Customer_name','Invoice_Quantity','Sales_Amount_(INR)','Net_Weight(KG)']].sort_values(by='Sales_Amount_(INR)', ascending = False).head(50)
# Out:
#                           Customer_name  Invoice_Quantity  Sales_Amount_(INR)  \
# 0                M/S RAJESH ENTERPRISES             23000          1092270.00
# 1                M/S RAJESH ENTERPRISES             90340           996450.20
# 2                M/S RAJESH ENTERPRISES             67615           745793.45
# 3                M/S RAJESH ENTERPRISES             60000           661800.00
# 4                   LPS BOSSARD PVT LTD            213500           617015.00
# 5                M/S RAJESH ENTERPRISES             50000           551500.00
# 6                M/S RAJESH ENTERPRISES             11539           547987.11
# 7                M/S RAJESH ENTERPRISES              2500           491895.00
# 8               NAV BHARAT SUPPLY STORE              2500           404750.00
# 9                M/S RAJESH ENTERPRISES              9000           377730.00
# 10               ECOPPIA SCIENTIFIC LLP              4040           355520.00
# ...

# %%
df.hist(figsize=(20,30));

# %%
plt.figure(figsize=(15,30))
sns.boxplot(x="Sales_Amount_(INR)", y='Customer_name', data=df, orient='h')
# Out:
# <AxesSubplot:xlabel='Sales_Amount_(INR)', ylabel='Customer_name'>

# %%
df.groupby("Customer_name").sum()["Sales_Amount_(INR)"].sort_values(ascending = False)
# Out:
# Customer_name
# M/S RAJESH ENTERPRISES                 8618793.26
# SANGHVI ENTERPRISES                    1599860.38
# KALINGA INDUSTRIAL SUPPLIER            1529339.07
# NAV BHARAT SUPPLY STORE                1328810.34
# UNIVERSAL PRECISION SCREWS             1084436.00
#                                           ...
# M/S MILL POINT                           13645.67
# OMKAR ENTERPRISES                        13637.73
# SUPER HARDWARE                           13006.63
# JAY SHREE AGENCIES                       11008.19
# NATIONAL ENGINEERING INDUSTRIES LTD       9564.20
# Name: Sales_Amount_(INR), Length: 101, dtype: float64

# %%
plt.figure(figsize=(25,20))
sns.barplot( x='Customer_name', y='Sales_Amount_(INR)', estimator = np.sum, data=df, ci=None)
plt.xticks(rotation=90);

# %%
cat = []
num = []
for i in df.columns:
    if df[i].dtype == 'object':
        cat.append(i)
    else:
        num.append(i)
print(cat)
print(num)
# Out:
# ['Customer_name', 'Description', 'Material Group', 'Part_Size', 'Sales_Organization', 'Sales_Person', 'Sub_Group', 'Sub_Group_Description']
# ['Invoice_Quantity', 'Unit_Weight(Grams)', 'Net_Weight(KG)', 'Sales_Amount_(INR)', 'Material_Cost']

# %%
df[num].describe().T
# Out:
#                      count          mean           std     min        25%  \
# Invoice_Quantity    2026.0   1867.649062   7177.449008    5.00   120.0000
# Unit_Weight(Grams)  2026.0    127.148157    207.622165    0.12    15.0250
# Net_Weight(KG)      2026.0     66.818870    294.313810    0.08     6.8600
# Sales_Amount_(INR)  2026.0  15144.236757  55804.651353  182.16  1935.3675
# Material_Cost       2026.0  10930.051155  44675.603162    0.00  1057.0500
#
#                          50%       75%        max
# Invoice_Quantity     400.000  1000.000   213500.0
# Unit_Weight(Grams)    46.500   139.750     3140.0
# Net_Weight(KG)        19.040    39.000     6881.6
# Sales_Amount_(INR)  4409.455  9332.075  1092270.0
# Material_Cost       2902.875  6105.375  1077320.0

# %%
df[cat].describe().T
# Out:
#                       count unique                               top  freq
# Customer_name          2026    101               SANDEEP ENGINEERING   298
# Description            2026    615  SHCS M10  x  30 12.9 F/T BLACK *    22
# Material Group         2026     10                              SHCS  1081
# Part_Size              2026      4                       Extra Heavy   763
# Sales_Organization     2026      1                               UPS  2026
# Sales_Person           2026      8                     JYOTI KAWATRA  1326
# Sub_Group              2025     13                              SHCS  1081
# Sub_Group_Description  2024      4                       ALLOY STEEL  2009

# %% [markdown]
# # Univariate Analysis of Continuous and Categorical variables

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),': ',df[column].nunique())
        print(df[column].value_counts().sort_values(ascending = False))
        print('\n')
# Out:
# CUSTOMER_NAME :  101
# SANDEEP ENGINEERING                    298
# GAJANAND TOOLS TRADERS                 125
# KAMBOJ TOOLS SYNDICATE                  90
# UNIVERSAL PRECISION SCREWS              72
# MANOJ TRADERS                           72
#                                       ...
# COGEME PRECISION PARTS INDIA PVT. L      1
# CARLISLE TRADING AND MANUFACTURING       1
# M/S GURUDEV SALES CORPORATION            1
# KOHLER POWER INDIA PRIVATE LIMITED       1
# KANTILAL & BROTHERS                      1
# Name: Customer_name, Length: 101, dtype: int64
#
#
# DESCRIPTION :  615
# SHCS M10  x  30 12.9 F/T BLACK *    22
# SHCS M8  x  30 12.9 F/T BLACK *     19
# HEX NUT M16X2 GR10*                 18
# HEX NUT M20X2.5 GR10*               18
# SHCS M6  x  20 12.9 F/T BLACK *     18
#                                     ..
# SHCS M5  x  50 12.9 H/T BLACK *      1
# CSK 3/8 UNC X 1 F/T BLACK*           1
# CSK M16X75 12.9 F/T BLACK*           1
# ...

# %% [markdown]
# # Univariate Analysis

# %%
df[df["Customer_name"]=="SANDEEP ENGINEERING"].groupby("Material Group").sum()["Sales_Amount_(INR)"].sort_values(ascending = False).head(20)
# Out:
# Material Group
# HEX HEAD     449770.63
# SHCS         402457.05
# NUT          117456.52
# SPL           52385.40
# CSK           39582.91
# ALLEN KEY      1833.00
# SSS            1608.00
# Name: Sales_Amount_(INR), dtype: float64

# %%
df[df["Customer_name"]=="SANDEEP ENGINEERING"].groupby("Part_Size").sum()["Sales_Amount_(INR)"].sort_values(ascending = False).head(20)
# Out:
# Part_Size
# Extra Heavy    499152.77
# Heavy          302170.40
# Extra Light    134030.51
# Medium         129739.83
# Name: Sales_Amount_(INR), dtype: float64

# %%
plt.figure(figsize=(25,10))
sns.barplot( x='Customer_name', y='Sales_Amount_(INR)',hue = "Part_Size", estimator = np.sum, data=df, ci=None)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(25,10))
sns.barplot( x='Customer_name', y='Sales_Amount_(INR)',hue = "Material Group", estimator = np.sum, data=df, ci=None)
plt.xticks(rotation=90);

# %%
df_San = df[df["Customer_name"]=="SANDEEP ENGINEERING"]

# %%
plt.figure(figsize=(50,7))
sns.barplot( x='Description', y='Sales_Amount_(INR)',hue = "Material Group", estimator = np.sum, data=df_San, ci=None)
plt.xticks(rotation=90);

# %%
for i in num:
    sns.boxplot(df[i],whis=2.0)
    plt.grid()
    plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.isnull().sum()
# Out:
# Customer_name            0
# Description              0
# Material Group           0
# Invoice_Quantity         0
# Unit_Weight(Grams)       0
# Part_Size                0
# Net_Weight(KG)           0
# Sales_Amount_(INR)       0
# Sales_Organization       0
# Material_Cost            0
# Sales_Person             0
# Sub_Group                1
# Sub_Group_Description    2
# dtype: int64

# %%
for column in ['Sub_Group','Sub_Group_Description']:
    df[column].fillna(df[column].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# Customer_name            0
# Description              0
# Material Group           0
# Invoice_Quantity         0
# Unit_Weight(Grams)       0
# Part_Size                0
# Net_Weight(KG)           0
# Sales_Amount_(INR)       0
# Sales_Organization       0
# Material_Cost            0
# Sales_Person             0
# Sub_Group                0
# Sub_Group_Description    0
# dtype: int64

# %%
df[column].mode()
# Out:
# 0    ALLOY STEEL
# Name: Sub_Group_Description, dtype: object

# %%
cont_cols = ['Invoice_Quantity','Unit_Weight(Grams)','Net_Weight(KG)','Sales_Amount_(INR)','Material_Cost']
for i in cont_cols:
    sns.boxplot(df[i],whis=1.5)
    plt.grid()
    plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.pairplot((df[cont_cols]), diag_kind='kde')  
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,mask=np.triu(df.corr(),+1));

# %%
Q1 = df.quantile(0.25) # Getting First quantile for all numerical variables
Q3 = df.quantile(0.75) # Getting Second quantile for all numerical variables
IQR = Q3 - Q1          # Getting IQR values
lower_range= Q1-(1.5 * IQR) #Getting Lower Limit for all numerical variables
upper_range= Q3+(1.5 * IQR) #Getting Upper Limit for all numerical variables

# %%
lower_range
# Out:
# Invoice_Quantity     -1200.00000
# Unit_Weight(Grams)    -172.06250
# Net_Weight(KG)         -41.35000
# Sales_Amount_(INR)   -9159.69375
# Material_Cost        -6515.43750
# dtype: float64

# %%
upper_range
# Out:
# Invoice_Quantity       2320.00000
# Unit_Weight(Grams)      326.83750
# Net_Weight(KG)           87.21000
# Sales_Amount_(INR)    20427.13625
# Material_Cost         13677.86250
# dtype: float64

# %%
df.describe(percentiles=[0.25,0.75,0.80,0.85,0.90,0.95,0.98,0.99]).T
# Out:
#                      count          mean           std     min        25%  \
# Invoice_Quantity    2026.0   1867.649062   7177.449008    5.00   120.0000
# Unit_Weight(Grams)  2026.0    127.148157    207.622165    0.12    15.0250
# Net_Weight(KG)      2026.0     66.818870    294.313810    0.08     6.8600
# Sales_Amount_(INR)  2026.0  15144.236757  55804.651353  182.16  1935.3675
# Material_Cost       2026.0  10930.051155  44675.603162    0.00  1057.0500
#
#                          50%       75%           80%        85%        90%  \
# Invoice_Quantity     400.000  1000.000   1600.000000   2000.000   4000.000
# Unit_Weight(Grams)    46.500   139.750    187.833333    259.715    375.000
# Net_Weight(KG)        19.040    39.000     50.200000     69.100    110.015
# Sales_Amount_(INR)  4409.455  9332.075  11785.860000  16004.835  25125.210
# Material_Cost       2902.875  6105.375   8240.000000  11106.700  18650.000
#
# ...

# %%
x = df[df["Sales_Amount_(INR)"]>= 1092270.0].sum()["Sales_Amount_(INR)"]

# %%
y = df["Sales_Amount_(INR)"].sum()

# %%
x/y*100
# Out:
# 3.559944063206811

# %% [markdown]
# # Most of values are present in outliers:so we should not treat outliers

# %%
df.describe()
# Out:
#        Invoice_Quantity  Unit_Weight(Grams)  Net_Weight(KG)  \
# count       2026.000000         2026.000000      2026.00000
# mean        1867.649062          127.148157        66.81887
# std         7177.449008          207.622165       294.31381
# min            5.000000            0.120000         0.08000
# 25%          120.000000           15.025000         6.86000
# 50%          400.000000           46.500000        19.04000
# 75%         1000.000000          139.750000        39.00000
# max       213500.000000         3140.000000      6881.60000
#
#        Sales_Amount_(INR)  Material_Cost
# count        2.026000e+03   2.026000e+03
# mean         1.514424e+04   1.093005e+04
# std          5.580465e+04   4.467560e+04
# min          1.821600e+02   0.000000e+00
# 25%          1.935367e+03   1.057050e+03
# 50%          4.409455e+03   2.902875e+03
# 75%          9.332075e+03   6.105375e+03
# max          1.092270e+06   1.077320e+06

# %%
df[num]
# Out:
#       Invoice_Quantity  Unit_Weight(Grams)  Net_Weight(KG)  \
# 0                23000          299.200000         6881.60
# 1                90340           64.599956         5835.96
# 2                67615           64.600015         4367.93
# 3                60000           64.600000         3876.00
# 4               213500            5.750023         1227.63
# ...                ...                 ...             ...
# 2021               200            3.150000            0.63
# 2022               200            1.650000            0.33
# 2023               200            0.400000            0.08
# 2024                74            4.594595            0.34
# 2025                22           45.909091            1.01
#
#       Sales_Amount_(INR)  Material_Cost
# 0             1092270.00     1077320.00
# 1              996450.20      752532.20
# 2              745793.45      563232.95
# 3              661800.00      499800.00
# 4              617015.00      508130.00
# ...

# %%
df.drop("Sales_Organization",axis = 1,inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_name          2026 non-null   object
#  1   Description            2026 non-null   object
#  2   Material Group         2026 non-null   object
#  3   Invoice_Quantity       2026 non-null   int64
#  4   Unit_Weight(Grams)     2026 non-null   float64
#  5   Part_Size              2026 non-null   object
#  6   Net_Weight(KG)         2026 non-null   float64
#  7   Sales_Amount_(INR)     2026 non-null   float64
#  8   Material_Cost          2026 non-null   float64
#  9   Sales_Person           2026 non-null   object
#  10  Sub_Group              2026 non-null   object
#  11  Sub_Group_Description  2026 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 190.1+ KB

# %% [markdown]
# # Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
wardlink = linkage(df[num], method = 'ward')

# %%
dend = dendrogram(wardlink)

# %%
dend = dendrogram(wardlink,
                 truncate_mode='lastp',
                 p = 10,
                 )

# %%
from scipy.cluster.hierarchy import fcluster

# %%
clusters = fcluster(wardlink, 100000, criterion='distance')
clusters
# Out:
# array([ 6,  7,  3, ..., 10, 10, 10], dtype=int32)

# %%
df['clusters'] = clusters

# %%
df.head()
# Out:
#             Customer_name                   Description Material Group  \
# 0  M/S RAJESH ENTERPRISES    HHB M20X100 GR 10.9 BLACK*       HEX HEAD
# 1  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 2  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 3  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 4     LPS BOSSARD PVT LTD  M6 X 16 SHCS (B16) Zn PHOSP*           SHCS
#
#    Invoice_Quantity  Unit_Weight(Grams)    Part_Size  Net_Weight(KG)  \
# 0             23000          299.200000  Extra Heavy         6881.60
# 1             90340           64.599956        Heavy         5835.96
# 2             67615           64.600015        Heavy         4367.93
# 3             60000           64.600000        Heavy         3876.00
# 4            213500            5.750023  Extra Light         1227.63
#
#    Sales_Amount_(INR)  Material_Cost   Sales_Person Sub_Group  \
# ...

# %%
df.to_csv('UPS JUNE DM 2022.csv')

# %% [markdown]
# # K Means

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = StandardScaler()

# %%
scaled_df = X.fit_transform(df[num])

# %%
scaled_df
# Out:
# array([[ 2.94499733,  0.82888221, 23.16052917, 19.30648541, 23.87551923],
#        [12.32947711, -0.30133412, 19.6068456 , 17.58900391, 16.60381025],
#        [ 9.16252874, -0.30133384, 14.61763891, 13.09621296, 12.36556899],
#        ...,
#        [-0.23240301, -0.61062579, -0.2268169 , -0.2676394 , -0.24417675],
#        [-0.24996233, -0.59041778, -0.22593327, -0.26784534, -0.2435212 ],
#        [-0.25720903, -0.3913798 , -0.22365623, -0.26818142, -0.24128094]])

# %%
k_means = KMeans(n_clusters = 2)

# %%
k_means.fit(scaled_df)
# Out:
# KMeans(n_clusters=2)

# %%
k_means.labels_
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
k_means.inertia_
# Out:
# 5522.122094020409

# %%
k_means = KMeans(n_clusters = 3)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 4160.36866984438

# %%
k_means = KMeans(n_clusters = 4)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 3078.3985525061407

# %%
k_means = KMeans(n_clusters = 5)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 2509.1183107294028

# %%
k_means = KMeans(n_clusters = 6)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 2076.13673143551

# %%
wss =[]

# %%
for i in range(1,11):
    KM = KMeans(n_clusters=i)
    KM.fit(scaled_df)
    wss.append(KM.inertia_)

# %%
wss
# Out:
# [10130.000000000004,
#  5522.12209402041,
#  4160.4731594467685,
#  3078.3985525061407,
#  2507.4286970113567,
#  2076.8111674636407,
#  1777.7507750927275,
#  1475.898252124974,
#  1301.2166770824708,
#  1159.076587432271]

# %%
plt.plot(range(1,11), wss)

# %%
k_means = KMeans(n_clusters = 5)
k_means.fit(scaled_df)
labels = k_means.labels_

# %%
df["Clus_kmeans"] = labels
df.head(5)
# Out:
#             Customer_name                   Description Material Group  \
# 0  M/S RAJESH ENTERPRISES    HHB M20X100 GR 10.9 BLACK*       HEX HEAD
# 1  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 2  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 3  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 4     LPS BOSSARD PVT LTD  M6 X 16 SHCS (B16) Zn PHOSP*           SHCS
#
#    Invoice_Quantity  Unit_Weight(Grams)    Part_Size  Net_Weight(KG)  \
# 0             23000          299.200000  Extra Heavy         6881.60
# 1             90340           64.599956        Heavy         5835.96
# 2             67615           64.600015        Heavy         4367.93
# 3             60000           64.600000        Heavy         3876.00
# 4            213500            5.750023  Extra Light         1227.63
#
#    Sales_Amount_(INR)  Material_Cost   Sales_Person Sub_Group  \
# ...

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silhouette_score(scaled_df,labels)
# Out:
# 0.6818243178744197

# %%
sil_width = silhouette_samples(scaled_df,labels)

# %%
df["sil_width"] = sil_width
df.head(5)
# Out:
#             Customer_name                   Description Material Group  \
# 0  M/S RAJESH ENTERPRISES    HHB M20X100 GR 10.9 BLACK*       HEX HEAD
# 1  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 2  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 3  M/S RAJESH ENTERPRISES         HEX NUT M20X2.5 GR10*            NUT
# 4     LPS BOSSARD PVT LTD  M6 X 16 SHCS (B16) Zn PHOSP*           SHCS
#
#    Invoice_Quantity  Unit_Weight(Grams)    Part_Size  Net_Weight(KG)  \
# 0             23000          299.200000  Extra Heavy         6881.60
# 1             90340           64.599956        Heavy         5835.96
# 2             67615           64.600015        Heavy         4367.93
# 3             60000           64.600000        Heavy         3876.00
# 4            213500            5.750023  Extra Light         1227.63
#
#    Sales_Amount_(INR)  Material_Cost   Sales_Person Sub_Group  \
# ...

# %%
silhouette_samples(scaled_df,labels).min()
# Out:
# -0.2886832374470706

# %%
df.to_csv('UPS JUNE DM 2022.csv')
